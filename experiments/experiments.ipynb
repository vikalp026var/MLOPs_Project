# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/firstproject/main/artifacts/raw.csv")

# %%
df
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table     x     y     z  \
# 0           1   0.30    Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33  Premium     G      IF   60.8   58.0  4.42  4.46  2.70
#
#    price
# 0    499
# 1    984

# %%
df.rename(columns={'Unnamed:0':'id'},inplace=True)

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 25403       25404   1.52      Ideal     J    VVS2   62.6   58.0  7.32  7.34
# 5256         5257   0.90  Very Good     D     SI2   58.8   59.0  6.24  6.28
# 11153       11154   0.46  Very Good     G    VVS1   61.7   60.0  4.94  4.98
# 20090       20091   0.71    Premium     G     VS2   60.3   60.0  5.76  5.81
# 9216         9217   0.27      Ideal     F     VS2   61.9   54.0  4.14  4.16
# 1585         1586   1.57      Ideal     G    VVS2    NaN   56.0  7.48  7.41
# 26637       26638   0.34      Ideal     E     VS1   62.8   56.0  4.46  4.49
# 1032         1033   0.90      Ideal     D     SI1   61.3   58.0  6.16  6.21
# 12728       12729   1.01      Ideal     E      I1   62.0   57.0  6.41  6.37
# 24919       24920   0.37    Premium     J     VS2   60.7   60.0  4.65  4.68
#
#           z  price
# 25403  4.59   9541
# 5256   3.68   3643
# 11153  3.06   1413
# 20090  3.49   2671
# 9216   2.57    583
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %%
mea=df['depth'].mean()
df['depth'].fillna(mea,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# x             0
# y             0
# z             0
# price         0
# dtype: int64

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26967 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x',
#        'y', 'z', 'price'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed: 0':'id'},inplace=True)

# %%
df
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1          2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2          3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3          4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4          5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 26962  26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09
# 26963  26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74
# 26964  26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17
# 26965  26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60
# 26966  26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27
#
#        price
# 0        499
# 1        984
# ...

# %%
df.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
df.drop(labels=['id'],axis=1,inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 34

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26933 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26933 non-null  float64
#  1   cut      26933 non-null  object
#  2   color    26933 non-null  object
#  3   clarity  26933 non-null  object
#  4   depth    26933 non-null  float64
#  5   table    26933 non-null  float64
#  6   x        26933 non-null  float64
#  7   y        26933 non-null  float64
#  8   z        26933 non-null  float64
#  9   price    26933 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.3+ MB

# %%
categorical_column=df.columns[df.dtypes=='object']

# %%
num_caolumn=df.columns[df.dtypes!='object']

# %%
num_caolumn
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
df[categorical_column]
# Out:
#              cut color clarity
# 0          Ideal     E     SI1
# 1        Premium     G      IF
# 2      Very Good     E    VVS2
# 3          Ideal     F     VS1
# 4          Ideal     F    VVS1
# ...          ...   ...     ...
# 26962    Premium     G     SI1
# 26963      Ideal     H      IF
# 26964    Premium     E     VS2
# 26965  Very Good     F    VVS2
# 26966    Premium     J     SI1
#
# [26933 rows x 3 columns]

# %%
df[num_caolumn]
# Out:
#        carat  depth  table     x     y     z  price
# 0       0.30   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31   60.4   59.0  4.35  4.43  2.65    779
# ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25   62.0   58.0  6.90  6.88  4.27   5166
#
# [26933 rows x 7 columns]

# %%
df[num_caolumn].describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  26933.0     0.798010     0.477237    0.2    0.40     0.70     1.05
# depth  26933.0    61.745282     1.393848   50.8   61.10    61.80    62.50
# table  26933.0    57.455950     2.232156   49.0   56.00    57.00    59.00
# x      26933.0     5.729346     1.127367    0.0    4.71     5.69     6.55
# y      26933.0     5.733102     1.165037    0.0    4.71     5.70     6.54
# z      26933.0     3.537769     0.719964    0.0    2.90     3.52     4.04
# price  26933.0  3937.526120  4022.551862  326.0  945.00  2375.00  5356.00
#
#             max
# carat      4.50
# depth     73.60
# table     79.00
# x         10.23
# y         58.90
# z         31.80
# price  18818.00

# %%
for column in categorical_column:
     print(df[column].value_counts())
     print(f"Length of the column :{len(df[column].value_counts())}")
     print("====================")
# Out:
# cut
# Ideal        10805
# Premium       6886
# Very Good     6027
# Good          2435
# Fair           780
# Name: count, dtype: int64
# Length of the column :5
# ...
# color
# G    5653
# E    4916
# F    4723
# H    4095
# D    3341
# I    2765
# J    1440
# Name: count, dtype: int64
# Length of the column :7
# ...
# clarity
# SI1     6565
# VS2     6093
# SI2     4564
# VS1     4087
# VVS2    2530
# VVS1    1839
# IF       891
# I1       364
# Name: count, dtype: int64
# Length of the column :8
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.figure(figsize=(6,4))

# %%
for col in num_caolumn:
     sns.histplot(data=df,x=col,kde=True)
     print("\n")
     plt.show()

# %%
sns.heatmap(df[num_caolumn].corr(),annot=True)
# Out:
# <Axes: >

# %%
df[categorical_column]
# Out:
#              cut color clarity
# 0          Ideal     E     SI1
# 1        Premium     G      IF
# 2      Very Good     E    VVS2
# 3          Ideal     F     VS1
# 4          Ideal     F    VVS1
# ...          ...   ...     ...
# 26962    Premium     G     SI1
# 26963      Ideal     H      IF
# 26964    Premium     E     VS2
# 26965  Very Good     F    VVS2
# 26966    Premium     J     SI1
#
# [26933 rows x 3 columns]

# %%
# sns.heatmap(df.corr(),annot=True)

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     6565
# VS2     6093
# SI2     4564
# VS1     4087
# VVS2    2530
# VVS1    1839
# IF       891
# I1       364
# Name: count, dtype: int64

# %%
clarity_map={'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8}

# %%
df['clarity']=df['clarity'].map(clarity_map)

# %%
df[categorical_column]
# Out:
#              cut color  clarity
# 0          Ideal     E        3
# 1        Premium     G        8
# 2      Very Good     E        6
# 3          Ideal     F        5
# 4          Ideal     F        7
# ...          ...   ...      ...
# 26962    Premium     G        3
# 26963      Ideal     H        8
# 26964    Premium     E        4
# 26965  Very Good     F        6
# 26966    Premium     J        3
#
# [26933 rows x 3 columns]

# %%
df.cut.value_counts(
)
# Out:
# cut
# Ideal        10805
# Premium       6886
# Very Good     6027
# Good          2435
# Fair           780
# Name: count, dtype: int64

# %%
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}

# %%
df['cut']=df['cut'].map(cut_map)

# %%
df[categorical_column]
# Out:
#        cut color  clarity
# 0        5     E        3
# 1        4     G        8
# 2        3     E        6
# 3        5     F        5
# 4        5     F        7
# ...    ...   ...      ...
# 26962    4     G        3
# 26963    5     H        8
# 26964    4     E        4
# 26965    3     F        6
# 26966    4     J        3
#
# [26933 rows x 3 columns]

# %%
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}

# %%
df['color']=df['color'].map(color_map)

# %%
df[categorical_column]
# Out:
#        cut  color  clarity
# 0        5      2        3
# 1        4      4        8
# 2        3      2        6
# 3        5      3        5
# 4        5      3        7
# ...    ...    ...      ...
# 26962    4      4        3
# 26963    5      5        8
# 26964    4      2        4
# 26965    3      3        6
# 26966    4      7        3
#
# [26933 rows x 3 columns]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# ...

# %%
X=df.drop(labels=['price'],axis=1)
y=df['price']

# %%
X
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z
# 0      2.66
# 1      2.70
# 2      3.78
# ...

# %%
y
# Out:
# 0         499
# 1         984
# 2        6289
# 3        1082
# 4         779
#          ...
# 26962    5408
# 26963    1114
# 26964    1656
# 26965     682
# 26966    5166
# Name: price, Length: 26967, dtype: int64

# %%
df['color'].value_counts()
print("=================")
df['clarity'].value_counts()
# Out:
# ...
# clarity
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: count, dtype: int64

# %%
df.drop(labels=['Unnamed: 0'],axis=1,inplace=True)

# %%
cut_categories=['Fair','Good','Very Good','Premium','Ideal']
color_categories=['D','E','F','G','H','I','J']
calrity_categories=['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']

# %%
num_pipeline=Pipeline(
     steps=[
          ("imputer",SimpleImputer()),
          ("scaler",StandardScaler())
          
     ]
)

# %%
cat_pipeline=Pipeline(
     steps=[
          ("imputer",SimpleImputer(strategy="most_frequent")),
          ("ordinalencoder",OrdinalEncoder(categories=[cut_categories,color_categories,calrity_categories]))
     ]
)

# %%
preprocessor=ColumnTransformer(
     [
          ("num_pipeline",num_pipeline,df[num_caolumn].columns.drop(labels=['price'])),
          ("categorical_pipeline",cat_pipeline,df[categorical_column].columns)
     ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                 ('categorical_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['Fair',
#                                                                               'Good',
#                                                                               'Very '
#                                                                               'Good',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 3658         3659   0.50  Very Good     G     SI1    NaN   52.0  5.10  5.15
# 257           258   1.53    Premium     G     VS1   61.0   60.0  7.43  7.40
# 2202         2203   1.00  Very Good     D     SI1   61.3   54.0  6.37  6.39
# 12272       12273   1.58    Premium     J    VVS2   61.0   58.0  7.56  7.49
# 13022       13023   0.72      Ideal     F     VS2   61.8   56.0  5.72  5.74
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 21575       21576   0.41      Ideal     F     VS1   60.8   57.0  4.77  4.80
# 5390         5391   0.33  Very Good     H     VS1   59.7   59.0  4.52  4.53
# 860           861   0.39      Ideal     G    VVS1    NaN   56.0  4.66  4.70
# 15795       15796   0.33      Ideal     J     SI1   61.1   56.0  4.49  4.55
# 23654       23655   0.31      Ideal     E     VS2   62.4   54.0  4.35  4.31
#
#           z
# 3658   3.20
# 257    4.52
# 2202   3.91
# ...

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %%
X_train
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 3658         3659   0.50  Very Good     G     SI1    NaN   52.0  5.10  5.15
# 257           258   1.53    Premium     G     VS1   61.0   60.0  7.43  7.40
# 2202         2203   1.00  Very Good     D     SI1   61.3   54.0  6.37  6.39
# 12272       12273   1.58    Premium     J    VVS2   61.0   58.0  7.56  7.49
# 13022       13023   0.72      Ideal     F     VS2   61.8   56.0  5.72  5.74
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 21575       21576   0.41      Ideal     F     VS1   60.8   57.0  4.77  4.80
# 5390         5391   0.33  Very Good     H     VS1   59.7   59.0  4.52  4.53
# 860           861   0.39      Ideal     G    VVS1    NaN   56.0  4.66  4.70
# 15795       15796   0.33      Ideal     J     SI1   61.1   56.0  4.49  4.55
# 23654       23655   0.31      Ideal     E     VS2   62.4   54.0  4.35  4.31
#
#           z
# 3658   3.20
# 257    4.52
# 2202   3.91
# ...

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-6.27970010e-01, -5.10431330e-15, -2.43676866e+00, ...,
#          2.00000000e+00,  3.00000000e+00,  2.00000000e+00],
#        [ 1.54029220e+00, -5.37637591e-01,  1.13527083e+00, ...,
#          3.00000000e+00,  3.00000000e+00,  4.00000000e+00],
#        [ 4.24584460e-01, -3.22127121e-01, -1.54375879e+00, ...,
#          2.00000000e+00,  0.00000000e+00,  2.00000000e+00],
#        ...,
#        [-8.59531993e-01, -5.10431330e-15, -6.50748916e-01, ...,
#          4.00000000e+00,  3.00000000e+00,  6.00000000e+00],
#        [-9.85838530e-01, -4.65800768e-01, -6.50748916e-01, ...,
#          4.00000000e+00,  6.00000000e+00,  2.00000000e+00],
#        [-1.02794071e+00,  4.68077937e-01, -1.54375879e+00, ...,
#          4.00000000e+00,  1.00000000e+00,  3.00000000e+00]])

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())

# %%
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                -0.627970        -5.104313e-15            -2.436769
# 1                 1.540292        -5.376376e-01             1.135271
# 2                 0.424584        -3.221271e-01            -1.543759
# 3                 1.645548        -5.376376e-01             0.242261
# 4                -0.164846         3.705700e-02            -0.650749
# ...                    ...                  ...                  ...
# 21568            -0.817430        -6.813112e-01            -0.204244
# 21569            -0.985839        -1.471516e+00             0.688766
# 21570            -0.859532        -5.104313e-15            -0.650749
# 21571            -0.985839        -4.658008e-01            -0.650749
# 21572            -1.027941         4.680779e-01            -1.543759
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  \
# 0            -0.561384        -0.522367        -0.485944
# ...

# %%
X_test
# Out:
#       num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                0.635095            -0.896822             1.135271
# 1               -0.817430             1.258283            -1.097254
# 2               -1.154247            -1.399679             0.688766
# 3                1.519241             0.755425            -0.650749
# 4               -0.796379             0.252567            -1.097254
# ...                   ...                  ...                  ...
# 5389            -0.564817             0.539915            -1.543759
# 5390             0.971913             0.539915            -0.650749
# 5391            -0.627970             0.324404             1.135271
# 5392            -0.185897            -1.615190             0.242261
# 5393             0.614044            -0.106617            -0.204244
#
#       num_pipeline__x  num_pipeline__y  num_pipeline__z  \
# 0            0.817008         0.839490         0.706565
# ...

# %%
from xgboost import XGBRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
models={
     'LinearRegression':LinearRegression(),
     'Lasso':Lasso(),
     'Ridge':Ridge(),
     'Elasticnet':ElasticNet(),
     'RandomForest':RandomForestRegressor(),
     'xgboost':XGBRegressor()
}

# %%
train_model_list=[]
model_list=[]
r2_list=[]

# %%
list(models)
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet', 'RandomForest', 'xgboost']

# %%
def evaluate_model(true,pred):
     r2_scor=r2_score(true,pred)
     mse=mean_squared_error(true,pred)
     mae=mean_absolute_error(true,pred)
     return r2_scor,mse,mae

# %%
for model_name,model in models.items():
     model.fit(X_train,y_train)
     y_pred=model.predict(X_test)
     print(f"model which is fitted is : {model_name}")
     r2_scor,mse,mae=evaluate_model(y_test,y_pred)
     r2_list.append(r2_scor)
     print(f" MSE of {model_name} is :{mse}")
     print(f"mae of {model_name} is :{mae}")
     print(f"r2_score of {model_name} is {r2_scor}")
     print("="*40)
     print("\n")
# Out:
# model which is fitted is : LinearRegression
#  MSE of LinearRegression is :3012597.4642252754
# mae of LinearRegression is :852.907966886382
# r2_score of LinearRegression is 0.8210677999990742
# ...
# c:\Users\PC\databaseauto\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.313e+08, tolerance: 3.460e+07
#   model = cd_fast.enet_coordinate_descent(
# model which is fitted is : Lasso
#  MSE of Lasso is :2055799.7960381606
# mae of Lasso is :845.2136089269706
# r2_score of Lasso is 0.8778964715217407
# ...
#
#
# model which is fitted is : Ridge
#  MSE of Ridge is :2910479.241757811
# mae of Ridge is :852.3601941837193
# r2_score of Ridge is 0.8271330770310278
# ...
#
#
# model which is fitted is : Elasticnet
#  MSE of Elasticnet is :3025974.2121061487
# mae of Elasticnet is :1095.8139879615353
# ...

# %%
r2_list
# Out:
# [0.8210677999990742,
#  0.8778964715217407,
#  0.8271330770310278,
#  0.8202732926161245,
#  0.9809220975899048,
#  0.9810822188318506]
